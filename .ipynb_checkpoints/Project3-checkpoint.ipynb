# %%
import cv2
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from utils import *
import os
#from scipy.sparse import csr_matrix
from scipy.sparse.linalg import lsqr
from scipy.sparse import csr_matrix

# %%
toy_img = cv2.cvtColor(cv2.imread('samples/toy_problem.png'), cv2.COLOR_BGR2RGB)
toy_img = cv2.cvtColor(toy_img, cv2.COLOR_BGR2GRAY).astype('double') / 255.0
plt.imshow(toy_img, cmap="gray")

# %%
toy_img.shape
# Out:
# (119, 110)

# %% [markdown]
# ## Part 1 Toy Problem (20 pts)

# %%
def toy_reconstruct(toy_img):
    """
    The implementation for gradient domain processing is not complicated, but it is easy to make a mistake, so let's start with a toy example. Reconstruct this image from its gradient values, plus one pixel intensity. Denote the intensity of the source image at (x, y) as s(x,y) and the value to solve for as v(x,y). For each pixel, then, we have two objectives:
    1. minimize (v(x+1,y)-v(x,y) - (s(x+1,y)-s(x,y)))^2
    2. minimize (v(x,y+1)-v(x,y) - (s(x,y+1)-s(x,y)))^2
    Note that these could be solved while adding any constant value to v, so we will add one more objective:
    3. minimize (v(1,1)-s(1,1))^2
    
    :param toy_img: numpy.ndarray
    """
    rows, cols = toy_img.shape
    
    im2var = np.arange(rows * cols).reshape(rows, cols)
    print(im2var)
    
    size_toy = toy_img.size
    
    
    equations_num = 2 * size_toy + 1
    
    A = np.zeros(shape = (equations_num, size_toy))
    b = np.zeros(shape = (equations_num, 1))
    e = 0
    

    
    for y in range(0,rows):
        for x in range(0, cols - 1):
            A[e][im2var[y][x+1]] = 1
            A[e][im2var[y][x]] = -1
            b[e] = toy_img[y][x+1] - toy_img[y][x]
            e = e + 1
    


            
    for y in range(0,rows -1):
        for x in range(0, cols):
            A[e][im2var[y+1][x]] = 1
            A[e][im2var[y][x]] = -1
            b[e] = toy_img[y+1][x] - toy_img[y][x]
            e = e + 1
            


    
    A[e][im2var[0][0]] = 1
    b[e] = toy_img[0][0]
    print("start")  
    print(A.shape)
    print(b.shape)
    v = lsqr(A, b)
    print("done")
    
    im_out = np.reshape(v[0], (rows, cols))
    
    return im_out

# %%
im_out = toy_reconstruct(toy_img)
# Out:
# [[    0     1     2 ...   107   108   109]
#  [  110   111   112 ...   217   218   219]
#  [  220   221   222 ...   327   328   329]
#  ...
#  [12760 12761 12762 ... 12867 12868 12869]
#  [12870 12871 12872 ... 12977 12978 12979]
#  [12980 12981 12982 ... 13087 13088 13089]]
# start
# (26181, 13090)
# (26181, 1)
# done

# %%
im_out
# Out:
# array([[0.34509988, 0.34510081, 0.34510143, ..., 0.34510012, 0.34510014,
#         0.34510012],
#        [0.34510083, 0.34510115, 0.34510159, ..., 0.34510016, 0.34510017,
#         0.34510013],
#        [0.34510142, 0.34510152, 0.34510176, ..., 0.34510029, 0.34510029,
#         0.34510024],
#        ...,
#        [0.34509328, 0.34509327, 0.34509327, ..., 0.34509293, 0.34509279,
#         0.34509275],
#        [0.34509314, 0.34509316, 0.3450932 , ..., 0.34509307, 0.34509293,
#         0.34509286],
#        [0.34509307, 0.34509308, 0.34509315, ..., 0.34509311, 0.34509299,
#         0.34509295]])

# %%
if im_out.any():
    print("Error is: ", np.sqrt(((im_out - toy_img)**2).sum()))
# Out:
# Error is:  0.0003170185007507367

# %%
#Images sanity check
fig, axes = plt.subplots(1, 2)
axes[0].imshow(toy_img,cmap='gray')
axes[1].imshow(im_out,cmap='gray')

# %% [markdown]
# ## Preparation

# %%
# Feel free to change image
background_img = cv2.cvtColor(cv2.imread('samples/im2.JPG'), cv2.COLOR_BGR2RGB).astype('double') / 255.0 
plt.figure()
plt.imshow(background_img)

# %%
# Feel free to change image
object_img = cv2.cvtColor(cv2.imread('samples/penguin-chick.jpeg'), cv2.COLOR_BGR2RGB).astype('double') / 255.0 
import matplotlib.pyplot as plt
# %matplotlib notebook
mask_coords = specify_mask(object_img)
# Out:
# If it doesn't get you to the drawing mode, then rerun this function again.
# <img src="data:image/png;base64,..." width="432">

# %%
xs = mask_coords[0]
ys = mask_coords[1]
# %matplotlib inline
import matplotlib.pyplot as plt
plt.figure()
mask = get_mask(ys, xs, object_img)

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
bottom_center = specify_bottom_center(background_img)
# Out:
# If it doesn't get you to the drawing mode, then rerun this function again. Also, make sure the object fill fit into the background image. Otherwise it will crash
# <img src="data:image/png;base64,..." width="432">

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
cropped_object, object_mask = align_source(object_img, mask, background_img, bottom_center)

# %%
object_mask.shape
# Out:
# (2816, 2112)

# %%
background_img.size
# Out:
# 17842176

# %% [markdown]
# ## Part 2 Poisson Blending (50 pts)

# %%
def poisson_blend(cropped_object, object_mask, background_img):
    """
    :param cropped_object: numpy.ndarray One you get from align_source
    :param object_mask: numpy.ndarray One you get from align_source
    :param background_img: numpy.ndarray 
    """
    #TO DO 
    
    
    
    background_rows = background_img.shape[0]
    background_cols = background_img.shape[1]
    background_count = background_rows * background_cols
    print(background_count)
    im2var =  np.arange(background_count).reshape(background_rows, background_cols)
    output = np.zeros(shape=(background_rows,background_cols,3))
    print(im2var)
    
   
    for z in range(2):
        v = []
        sparse_value = []
        sparse_row = []
        sparse_col = []
        b = np.zeros(shape = (background_count,1))
        e = 0
        #A =  np.zeros(shape=(background_count,background_count))
        
        for y in range(background_rows):
            for x in range(background_cols):
                if not object_mask[y,x]: #background only
                    #sparse_1.append(e + 1)
                    #sparse_2.append(im2var[y,x])
                    #sparse_3.append(1)
                    #A[e][im2var[y,x]] = 1
                    sparse_value.append(1)
                    sparse_row.append(e)
                    sparse_col.append(im2var[y,x])
                    b[e] = background_img[y,x,z]
                    e = e + 1
                    
                else:
                    if object_mask[y,x+1]:
                        #sparse_1.append(e + 1)
                        #sparse_2.append(im2var[y,x+1])
                        #sparse_3.append(-1)
                        #A[e][im2var[y,x+1]] = -1
                        sparse_value.append(-1)
                        sparse_row.append(e)
                        sparse_col.append(im2var[y,x + 1])
                        
                        
                        
                    if object_mask[y,x-1]:
                        #sparse_1.append(e)
                        #sparse_2.append(im2var[y,x-1])
                        #sparse_3.append(-1)
                        #A[e][im2var[y,x-1]] = -1
                        sparse_value.append(-1)
                        sparse_row.append(e)
                        sparse_col.append(im2var[y,x - 1])
                        
                    if object_mask[y+1,x]:
                        #sparse_1.append(e + 1)
                        #sparse_2.append(im2var[y+1,x])
                        #sparse_3.append(-1)
                        #A[e][im2var[y+1,x]] = -1
                        sparse_value.append(-1)
                        sparse_row.append(e)
                        sparse_col.append(im2var[y+1,x])
                        
                    if object_mask[y-1,x]:
                        #sparse_1.append(e + 1)
                        #sparse_2.append(im2var[y-1,x])
                        #sparse_3.append(-1)
                        #A[e][im2var[y-1,x]] = -1
                        sparse_value.append(-1)
                        sparse_row.append(e)
                        sparse_col.append(im2var[y-1,x])
                    
                    #sparse_1.append(e + 1)
                    #sparse_2.append(im2var[y,x])
                    #sparse_3.append(4)
                    #A[e][im2var[y,x]] = 4
                    sparse_value.append(4)
                    sparse_row.append(e)
                    sparse_col.append(im2var[y,x])
                    
                    
                    b[e] = 0
                    b[e] = (cropped_object[y,x,z] * 4) - cropped_object[y,x+1,z] - cropped_object[y,x - 1,z] - cropped_object[y+1,x,z] - cropped_object[y-1,x,z]
                    
                    if not object_mask[y,x+1]:
                        b[e] = b[e] + background_img[y,x+1,z]
                    if not object_mask[y,x-1]:
                        b[e] = b[e] + background_img[y,x-1,z]
                    if not object_mask[y+1,x]:
                        b[e] = b[e] + background_img[y+1,x,z]
                    if not object_mask[y-1,x]:
                        b[e] = b[e] + background_img[y-1,x,z]
                        
                    e = e + 1
        sparse_value = np.asarray(sparse_value)
        sparse_row = np.asarray(sparse_row)
        sparse_col = np.asarray(sparse_col)
        print(sparse_value.shape)
        print(sparse_row.shape)
        print(sparse_col.shape)
        print(b.shape)
        print(e)
        #return 0
        A = csr_matrix((sparse_value, (sparse_row, sparse_col)), shape=(background_count, background_count)).toarray()
        print(z)
        v = lsqr(A, b)
        output[:,:,z] = np.reshape(v[0], (background_rows, background_cols))
        
    return output
                    
                    
                    
        
    
    
    
    
   
    pass

# %%
im_blend = poisson_blend(cropped_object, object_mask, background_img)
if im_blend.any():
    # %matplotlib inline
    import matplotlib.pyplot as plt
    plt.imshow(im_blend)
# Out:
# 5947392
# [[      0       1       2 ...,    2109    2110    2111]
#  [   2112    2113    2114 ...,    4221    4222    4223]
#  [   4224    4225    4226 ...,    6333    6334    6335]
#  ...,
#  [5941056 5941057 5941058 ..., 5943165 5943166 5943167]
#  [5943168 5943169 5943170 ..., 5945277 5945278 5945279]
#  [5945280 5945281 5945282 ..., 5947389 5947390 5947391]]
# (6444182,)
# (6444182,)
# (6444182,)
# (5947392, 1)
# 5947392
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-10-3abfea6f74d1> in <module>()
# ----> 1 im_blend = poisson_blend(cropped_object, object_mask, background_img)
#       2 if im_blend.any():
#       3     get_ipython().magic('matplotlib inline')
#       4     import matplotlib.pyplot as plt
#       5     plt.imshow(im_blend)
#
# <ipython-input-9-b51702ba3b11> in poisson_blend(cropped_object, object_mask, background_img)
#     110         print(e)
#     111         #return 0
# --> 112         A = csr_matrix((sparse_value, (sparse_row, sparse_col)), shape=(background_count, background_count)).toarray()
#     113         print(z)
#     114         v = lsqr(A, b)
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\scipy\sparse\compressed.py in toarray(self, order, out)
#     962     def toarray(self, order=None, out=None):
#     963         """See the docstring for `spmatrix.toarray`."""
# --> 964         return self.tocoo(copy=False).toarray(order=order, out=out)
#     965
#     966     ##############################################################
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\scipy\sparse\coo.py in toarray(self, order, out)
#     250     def toarray(self, order=None, out=None):
#     251         """See the docstring for `spmatrix.toarray`."""
# --> 252         B = self._process_toarray_args(order, out)
#     253         fortran = int(B.flags.f_contiguous)
#     254         if not fortran and not B.flags.c_contiguous:
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\scipy\sparse\base.py in _process_toarray_args(self, order, out)
#    1037             return out
#    1038         else:
# -> 1039             return np.zeros(self.shape, dtype=self.dtype, order=order)
#    1040
#    1041     def __numpy_ufunc__(self, func, method, pos, inputs, **kwargs):
#
# MemoryError:

# %% [markdown]
# ## Part 3 Mixed Gradients (20 pts)

# %%
def mix_blend(cropped_object, object_mask, background_img):
    """
    :param cropped_object: numpy.ndarray One you get from align_source
    :param object_mask: numpy.ndarray One you get from align_source
    :param background_img: numpy.ndarray 
    """
    
    
    
    #TO DO 
    pass

# %%
im_mix = mix_blend(cropped_object, object_mask, background_img)
if im_mix.any():
    # %matplotlib inline
    import matplotlib.pyplot as plt
    plt.imshow(im_mix)

# %% [markdown]
# # Bells & Whistles (Extra Points)

# %% [markdown]
# ## Color2Gray (20 pts)

# %%
def color2gray(img):
    pass

# %% [markdown]
# ## Laplacian pyramid blending (20 pts)

# %%
def laplacian_blend(img1, img2):
    pass

# %% [markdown]
# ## More gradient domain processing (up to 20 pts)
